# %%
import pandas as pd
import numpy as np 
from datetime import datetime, timedelta
import time
planning = pd.read_csv("planning.csv")
planning
# Out:
#    Unnamed: 0        date               activity1  Unnamed: 3
# 0           0  31:05:2020  Code/14:00:00/14:43:50         NaN

# %%
import matplotlib.pyplot as plt
labels = 'Code=> \n14:00:00\n14:43:50', 'Anglais=> \n14:00:00\n14:43:50', 'Dev=> \n14:00:00\n14:43:50', 'Libre=> \n14:00:00\n14:43:50'
sizes = [0.125, 0.250, 0.375,  0.500]
explode = (0, 0, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', counterclock=False, startangle=90)
ax1.axis('equal')

plt.show()

# %%
array = planning.iloc[0]["activity1"].split("/")
array
# Out:
# ['Code', '14:00:00', '14:43:50']

# %%
import matplotlib.pyplot as plt
activity1 = f"{array[0]} => \n{array[1]}\n{array[2]}"
labels = activity1, 'Anglais=> \n14:00:00\n14:43:50', 'Dev=> \n14:00:00\n14:43:50', 'Libre=> \n14:00:00\n14:43:50')
sizes = [0.125, 0.250, 0.375,  0.500]
explode = (0, 0, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', counterclock=False, startangle=90)
ax1.axis('equal')

plt.show()

# %%
a = 1,2
a = a +2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-056ed83da09e> in <module>
#       1 a = 1,2
# ----> 2 a = a +2
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
a
# Out:
# (1, 2)
